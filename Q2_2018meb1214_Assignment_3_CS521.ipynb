# %%
import numpy as np
import pandas as pd
import seaborn as sns
import math
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.datasets import load_iris
data=load_iris()

X=data.data
y=data.target
a=data.target_names
df=pd.DataFrame(X,columns=data.feature_names)
df['Class']=y
df
# Out:
#      sepal length (cm)  sepal width (cm)  ...  petal width (cm)  Class
# 0                  5.1               3.5  ...               0.2      0
# 1                  4.9               3.0  ...               0.2      0
# 2                  4.7               3.2  ...               0.2      0
# 3                  4.6               3.1  ...               0.2      0
# 4                  5.0               3.6  ...               0.2      0
# ..                 ...               ...  ...               ...    ...
# 145                6.7               3.0  ...               2.3      2
# 146                6.3               2.5  ...               1.9      2
# 147                6.5               3.0  ...               2.0      2
# 148                6.2               3.4  ...               2.3      2
# 149                5.9               3.0  ...               1.8      2
#
# [150 rows x 5 columns]

# %%
X
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X=scaler.fit_transform(X)

# %%
#PCA
from sklearn.decomposition import PCA

comp=100
pca=PCA(n_components=2)
pca.fit(X)

X_pca=pca.transform(X)
#X_test_pca=pca.transform(X_test)
#X_train_pca.shape
X_pca.shape
# Out:
# (150, 2)

# %%
a1=[]
a2=[]
a3=[]
a4=[]
colors=np.array(['r','b','g'])
for i in range(0,150):
    if df['sepal length (cm)'][i]> df['sepal length (cm)'].mean():
        a1.append(0)
    else:
         a1.append(1)
    if df['sepal width (cm)'][i]> df['sepal width (cm)'].mean():
        a2.append(0)
    else:
         a2.append(1)         
    if df['petal length (cm)'][i]> df['petal length (cm)'].mean():
        a3.append(0)
    else:
         a3.append(1)
    if df['petal width (cm)'][i]> df['petal width (cm)'].mean():
        a4.append(0)
    else:
        a4.append(1)

# %%
def irisplot(x, y, title, xlabel="1st eigenvector", ylabel="2nd eigenvector"):
    plt.scatter(x, y,c=colors[a1],s=55 ) #c=df['sepal length (cm)'],
    plt.title(title, fontsize='15')
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.text(0,0.9,'Red: High values (Above average)')
    plt.text(0,0.8,'Blue: Low values (Below average)')

irisplot(x=X_pca[:,0],y=X_pca[:,1],title=' PCA- Characterization through sepal length(2 dimensions)')

# %%
#cl=['low value','high value']
def irisplot(x, y, title, xlabel="1st eigenvector", ylabel="2nd eigenvector"):
    scatter=plt.scatter(x, y,c=colors[a2],s=55 ) #c=df['sepal width (cm)']
    plt.title(title, fontsize='15')
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.text(0,0.9,'Red: High values (Above average)')
    plt.text(0,0.8,'Blue: Low values (Below average)')
    #plt.legend(handles=scatter.legend_elements()[0], labels=[cl])

irisplot(x=X_pca[:,0],y=X_pca[:,1],title=' PCA- Characterization through sepal width')

# %%
def irisplot(x, y, title, xlabel="1st eigenvector", ylabel="2nd eigenvector"):
    plt.scatter(x, y,c=colors[a3],s=55 )  #c=df['petal length (cm)']
    plt.title(title, fontsize='15')
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.text(0,0.9,'Red: High values (Above average)')
    plt.text(0,0.8,'Blue: Low values (Below average)')

irisplot(x=X_pca[:,0],y=X_pca[:,1],title=' PCA- Characterization through petal length')

# %%
def irisplot(x, y, title, xlabel="1st eigenvector", ylabel="2nd eigenvector"):
    plt.scatter(x, y,c=colors[a4],s=55 ) # c=df['petal width (cm)']
    plt.title(title, fontsize='15')
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.text(0,0.9,'Red: High values (Above average)')
    plt.text(0,0.8,'Blue: Low values (Below average)')

irisplot(x=X_pca[:,0],y=X_pca[:,1],title=' PCA- Characterization through petal width')

# %%
eig_vals = pca.explained_variance_
eig_vecs= pca.components_

# %%
#cov_mat=pca
#eig_vals, eig_vecs = np.linalg.eig(cov_mat)

idx = np.argsort(eig_vals, axis=0)[::-1]
sorted_eig_vecs = eig_vecs[:, idx]
sc = np.dot(X_pca, sorted_eig_vecs[:, :2])

# %%
#y1=y[:100]
#X1=X[:100]

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
lda = LinearDiscriminantAnalysis(n_components=2)
#X_lda1 = lda.fit(X1, y1).transform(X1)
X_lda = lda.fit(X, y).transform(X)
X_lda
# Out:
# array([[ 8.06179978e+00,  3.00420621e-01],
#        [ 7.12868772e+00, -7.86660426e-01],
#        [ 7.48982797e+00, -2.65384488e-01],
#        [ 6.81320057e+00, -6.70631068e-01],
#        [ 8.13230933e+00,  5.14462530e-01],
#        [ 7.70194674e+00,  1.46172097e+00],
#        [ 7.21261762e+00,  3.55836209e-01],
#        [ 7.60529355e+00, -1.16338380e-02],
#        [ 6.56055159e+00, -1.01516362e+00],
#        [ 7.34305989e+00, -9.47319209e-01],
#        [ 8.39738652e+00,  6.47363392e-01],
#        [ 7.21929685e+00, -1.09646389e-01],
#        [ 7.32679599e+00, -1.07298943e+00],
#        [ 7.57247066e+00, -8.05464137e-01],
#        [ 9.84984300e+00,  1.58593698e+00],
#        [ 9.15823890e+00,  2.73759647e+00],
#        [ 8.58243141e+00,  1.83448945e+00],
#        [ 7.78075375e+00,  5.84339407e-01],
#        [ 8.07835876e+00,  9.68580703e-01],
#        [ 8.02097451e+00,  1.14050366e+00],
#        [ 7.49680227e+00, -1.88377220e-01],
#        [ 7.58648117e+00,  1.20797032e+00],
# ...

# %%
from mlxtend.plotting import plot_decision_regions
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.svm import SVC
svm = SVC(C=0.5, kernel='linear')
svm.fit(X_lda, y)
plot_decision_regions(X_lda, y, clf=svm)
plt.title('LDA in 2D')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/mlxtend/plotting/decision_regions.py:244: MatplotlibDeprecationWarning: Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
#   ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())

# %%
fig = plt.figure(figsize = (8,8))

setosa_versicolor = data.data[0:100,0:3]
setosa_versicolor_tgts = data.target[0:100]
versicolor_virg = data.data[50:150,0:3]
versicolor_virg_tgts = data.target[50:150]

setosa_virginica = np.concatenate((data.data[0:50,0:3], data.data[100:150,0:3]), axis=0)
setosa_virginica_tgts = np.concatenate((data.target[0:50], data.target[100:150]), axis=0)
s1=["setosa","versicolor"]
s2=["versicolor","virginica"]
s3=["setosa","virginica"]

def separation(X_lda, targets, id_1, id_2):
    mean_class_1 = X_lda[targets==id_1,0]
    mean_class_2 = X_lda[targets==id_2,0]
    result_mean = (np.mean(mean_class_1) + np.mean(mean_class_1))/2
    return result_mean.round(decimals=15)

def scatterPlot(X_lda,targets,id_1, id_2,text):
    for color, i, a1 in zip(['red', 'blue'], [id_1, id_2], a):
        plt.scatter(X_lda[targets==i,0], np.zeros([50]), color=color, label=a1)
        plt.title("Scatter plot for " + text + " classification")
    #plt.legend()
    plt.plot([0,0],[-0.04,0.04])
    plt.show()
    #plt.plot(str(s),0,'x')

lda_result = (lda.fit(setosa_versicolor, setosa_versicolor_tgts).transform(setosa_versicolor))

scatterPlot(lda_result,setosa_versicolor_tgts,0,1,"setosa and versicolor")
s = separation(lda.fit(setosa_versicolor, setosa_versicolor_tgts).transform(setosa_versicolor),setosa_versicolor_tgts,0,1)  
print("Threshold:" + str(s))
plt.axvline(str(s),0,1, label='Threshold line')
plt.legend()
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/discriminant_analysis.py:463: ChangedBehaviorWarning: n_components cannot be larger than min(n_features, n_classes - 1). Using min(n_features, n_classes - 1) = min(3, 2 - 1) = 1 components.
#   ChangedBehaviorWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/discriminant_analysis.py:469: FutureWarning: In version 0.23, setting n_components > min(n_features, n_classes - 1) will raise a ValueError. You should set n_components to None (default), or a value smaller or equal to min(n_features, n_classes - 1).
#   warnings.warn(future_msg, FutureWarning)
# Threshold:-4.805763011979293
# /usr/local/lib/python3.6/dist-packages/sklearn/discriminant_analysis.py:463: ChangedBehaviorWarning: n_components cannot be larger than min(n_features, n_classes - 1). Using min(n_features, n_classes - 1) = min(3, 2 - 1) = 1 components.
#   ChangedBehaviorWarning)
# ...

# %%
fig = plt.figure(figsize = (8,8))
lda_result = (lda.fit(setosa_virginica,setosa_virginica_tgts).transform(setosa_virginica))

scatterPlot(lda_result,setosa_virginica_tgts,0,2,"versicolor and virginica")
s = separation(lda.fit(setosa_virginica,setosa_virginica_tgts).transform(setosa_virginica),setosa_virginica_tgts,0,2)
print("Threshold:" + str(s))
plt.axvline(str(s),0,1, label='Threshold line')
plt.legend()
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/discriminant_analysis.py:463: ChangedBehaviorWarning: n_components cannot be larger than min(n_features, n_classes - 1). Using min(n_features, n_classes - 1) = min(3, 2 - 1) = 1 components.
#   ChangedBehaviorWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/discriminant_analysis.py:469: FutureWarning: In version 0.23, setting n_components > min(n_features, n_classes - 1) will raise a ValueError. You should set n_components to None (default), or a value smaller or equal to min(n_features, n_classes - 1).
#   warnings.warn(future_msg, FutureWarning)
# Threshold:-6.108499551588142
# /usr/local/lib/python3.6/dist-packages/sklearn/discriminant_analysis.py:463: ChangedBehaviorWarning: n_components cannot be larger than min(n_features, n_classes - 1). Using min(n_features, n_classes - 1) = min(3, 2 - 1) = 1 components.
#   ChangedBehaviorWarning)
# ...

# %%
fig = plt.figure(figsize = (8,8))

lda_result = (lda.fit(versicolor_virg,versicolor_virg_tgts).transform(versicolor_virg))

scatterPlot(lda_result,versicolor_virg_tgts,1,2,"setosa and virginica")
s = separation(lda.fit(versicolor_virg,versicolor_virg_tgts).transform(versicolor_virg),versicolor_virg_tgts,1,2)
print("Threshold:" + str(s))
plt.axvline(str(s),0,1, label='Threshold line')
plt.legend()
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/discriminant_analysis.py:463: ChangedBehaviorWarning: n_components cannot be larger than min(n_features, n_classes - 1). Using min(n_features, n_classes - 1) = min(3, 2 - 1) = 1 components.
#   ChangedBehaviorWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/discriminant_analysis.py:469: FutureWarning: In version 0.23, setting n_components > min(n_features, n_classes - 1) will raise a ValueError. You should set n_components to None (default), or a value smaller or equal to min(n_features, n_classes - 1).
#   warnings.warn(future_msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/discriminant_analysis.py:463: ChangedBehaviorWarning: n_components cannot be larger than min(n_features, n_classes - 1). Using min(n_features, n_classes - 1) = min(3, 2 - 1) = 1 components.
#   ChangedBehaviorWarning)
# Threshold:-1.5104177907815
# ...

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
lda = LinearDiscriminantAnalysis(n_components=2)
X_lda = lda.fit(X, y).transform(X)
X_lda.shape
# Out:
# (150, 2)

# %%
def irisplot(x, y, title, xlabel="Dimension 1", ylabel="Dimension 2"):
    plt.scatter(x, y,c=y,s=55) 
    plt.title(title, fontsize='15')
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)

irisplot(x=X_lda[:,0],y=X_lda[:,1],title='Iris Dataset in 2 dimensions through LDA')

# %% [markdown]
# Q2 Part(3)

# %%
#tsne 2D with metric= Euclidean
from sklearn.manifold import TSNE

tsne = TSNE(n_components=2, n_iter=1000, metric='euclidean')
X_tsne = tsne.fit_transform(X)

irisplot(x=X_tsne[:,0],y=X_tsne[:,1],title='(metric= Euclidean)Iris Dataset in 2 dimensions through t-SNE')

# %%
#tsne 2D with metric= cosine
from sklearn.manifold import TSNE

tsne = TSNE(n_components=2, n_iter=1000, metric='cosine')
X_tsne = tsne.fit_transform(X)

irisplot(x=X_tsne[:,0],y=X_tsne[:,1],title='(metric= cosine)Iris Dataset in 2 dimensions through t-SNE')

# %%
#tsne 2D with metric= chebyshev
from sklearn.manifold import TSNE

tsne = TSNE(n_components=2, n_iter=1000, metric='chebyshev')
X_tsne = tsne.fit_transform(X)

irisplot(x=X_tsne[:,0],y=X_tsne[:,1],title='(metric= chebyshev)Iris Dataset in 2 dimensions through t-SNE')

# %%
from mpl_toolkits.mplot3d import Axes3D
def irisplot3D(x, y,z, title, xlabel="Dimension 1", ylabel="Dimension 2",zlabel="Dimension 3"):
    fig = plt.figure(1, figsize=(8, 8))
    axes = Axes3D(fig, elev=-150)
    axes.scatter(x, y,z,c=y,s=45 ) 
    axes.set_title(title, fontsize='25')
    axes.set_xlabel(xlabel)
    axes.set_ylabel(ylabel)
    axes.set_zlabel(zlabel)

# %%
#tsne 3D with metric= Euclidean
from sklearn.manifold import TSNE

tsne = TSNE(n_components=3, n_iter=2000, metric='euclidean')
X_tsne = tsne.fit_transform(X)

irisplot3D(x=X_tsne[:,0],y=X_tsne[:,1],z=X_tsne[:,2],title='(metric=euclidean)Iris Dataset in 3 dimensions through t-SNE ')

# %%
#tsne 3D with metric= Cosine
from sklearn.manifold import TSNE

tsne = TSNE(n_components=3, n_iter=2000, metric='cosine')
X_tsne = tsne.fit_transform(X)

irisplot3D(x=X_tsne[:,0],y=X_tsne[:,1],z=X_tsne[:,2],title='(metric=cosine)Iris Dataset in 3 dimensions through t-SNE')
