# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.datasets import load_iris
data=load_iris()

X=data.data
y=data.target
a=data.target_names
df=pd.DataFrame(X,columns=data.feature_names)
df['Class']=y
df
# Out:
#      sepal length (cm)  sepal width (cm)  ...  petal width (cm)  Class
# 0                  5.1               3.5  ...               0.2      0
# 1                  4.9               3.0  ...               0.2      0
# 2                  4.7               3.2  ...               0.2      0
# 3                  4.6               3.1  ...               0.2      0
# 4                  5.0               3.6  ...               0.2      0
# ..                 ...               ...  ...               ...    ...
# 145                6.7               3.0  ...               2.3      2
# 146                6.3               2.5  ...               1.9      2
# 147                6.5               3.0  ...               2.0      2
# 148                6.2               3.4  ...               2.3      2
# 149                5.9               3.0  ...               1.8      2
#
# [150 rows x 5 columns]

# %%
#from sklearn.preprocessing import MinMaxScaler
#scaler = MinMaxScaler()
#X=scaler.fit_transform(X)

# %%
df=df.drop(columns=["sepal width (cm)","sepal length (cm)"])
df
# Out:
#      petal length (cm)  petal width (cm)  Class
# 0                  1.4               0.2      0
# 1                  1.4               0.2      0
# 2                  1.3               0.2      0
# 3                  1.5               0.2      0
# 4                  1.4               0.2      0
# ..                 ...               ...    ...
# 145                5.2               2.3      2
# 146                5.0               1.9      2
# 147                5.2               2.0      2
# 148                5.4               2.3      2
# 149                5.1               1.8      2
#
# [150 rows x 3 columns]

# %%
X=df[['petal length (cm)','petal width (cm)']]
#X=df[['sepal length (cm)','sepal width (cm)']]
X=X.to_numpy()

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

from sklearn import svm
from sklearn.svm import SVC

model=SVC(kernel='linear')
model.fit(X_train, y_train)
y_pred=model.predict(X_test)

from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))

clf=svm.SVC(kernel='linear')
clf.fit(X, y)

plt.scatter(X[:, 0], X[:, 1], c=y,s=40)
plt.title("Using SVM on all 3 classes and 2 features")
plt.xlabel('petal length (cm)')
plt.ylabel('petal width (cm)')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       0.94      0.94      0.94        18
#            2       0.92      0.92      0.92        13
#
#     accuracy                           0.96        45
#    macro avg       0.96      0.96      0.96        45
# weighted avg       0.96      0.96      0.96        45

# %%
X=df[['petal length (cm)','petal width (cm)']]
X=X.to_numpy()

X=X[50:150,:]
y=y[50:150]

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

from sklearn import svm
from sklearn.svm import SVC

model=SVC(kernel='linear')
model.fit(X_train, y_train)
y_pred=model.predict(X_test)

from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))

clf=svm.SVC(kernel='linear')
clf.fit(X, y)

plt.scatter(X[:, 0], X[:, 1], c=y,s=40)

ax = plt.gca()

X1 = np.linspace(ax.get_xlim()[0], ax.get_xlim()[1], 30)
y1 = np.linspace(ax.get_ylim()[0], ax.get_ylim()[1], 30)
y2, X2 = np.meshgrid(y1, X1)

stacked = np.vstack([X2.ravel(), y2.ravel()]).T #returns a flattened array
z = clf.decision_function(stacked).reshape(X2.shape)

ax.contour(X2, y2, z, colors='black', levels=[-1, 0, 1], linestyles=['--', '-', '--'])
ax.scatter(clf.support_vectors_[:, 0], clf.support_vectors_[:, 1], s=110,facecolors='none', edgecolors='black')

plt.title("virginica and virsicolor")
plt.xlabel('petal length (cm)')
plt.ylabel('petal width (cm)')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            1       0.86      0.86      0.86        14
#            2       0.88      0.88      0.88        16
#
#     accuracy                           0.87        30
#    macro avg       0.87      0.87      0.87        30
# weighted avg       0.87      0.87      0.87        30

# %%
X=df[['petal length (cm)','petal width (cm)']]
X=X.to_numpy()
y=data.target

X=X[0:100,:]
y=y[0:100]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

from sklearn import svm
from sklearn.svm import SVC

model=SVC(kernel='linear')
model.fit(X_train, y_train)
y_pred=model.predict(X_test)

from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))

clf=svm.SVC(kernel='linear')
clf.fit(X, y)


plt.scatter(X[:, 0], X[:, 1], c=y,s=40)
ax = plt.gca()

X1 = np.linspace(ax.get_xlim()[0], ax.get_xlim()[1], 30)
y1 = np.linspace(ax.get_ylim()[0], ax.get_ylim()[1], 30)
y2, X2 = np.meshgrid(y1, X1)

stacked = np.vstack([X2.ravel(), y2.ravel()]).T #returns a flattened array
z = clf.decision_function(stacked).reshape(X2.shape)

ax.contour(X2, y2, z, colors='black', levels=[-1, 0, 1], linestyles=['--', '-', '--'])
ax.scatter(clf.support_vectors_[:, 0], clf.support_vectors_[:, 1], s=110,facecolors='none', edgecolors='black')

plt.xlabel('petal length (cm)')
plt.ylabel('petal width (cm)')
plt.title("setosa and virsicolor")
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      1.00      1.00        16
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %%
X=df[['petal length (cm)','petal width (cm)']]
X=X.to_numpy()
y=data.target

#X=X[0:50,:]
X=np.concatenate((X[0:50,:],X[100:150,:]))
y=np.concatenate((y[0:50],y[100:150]))

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

from sklearn import svm
from sklearn.svm import SVC

model=SVC(kernel='linear')
model.fit(X_train, y_train)
y_pred=model.predict(X_test)

from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))

clf=svm.SVC(kernel='linear')
clf.fit(X, y)


plt.scatter(X[:, 0], X[:, 1], c=y,s=40)
ax = plt.gca()

X1 = np.linspace(ax.get_xlim()[0], ax.get_xlim()[1], 30)
y1 = np.linspace(ax.get_ylim()[0], ax.get_ylim()[1], 30)
y2, X2 = np.meshgrid(y1, X1)

stacked = np.vstack([X2.ravel(), y2.ravel()]).T #returns a flattened array
z = clf.decision_function(stacked).reshape(X2.shape)
ax.contour(X2, y2, z, colors='black', levels=[-1, 0, 1], linestyles=['--', '-', '--'])
ax.scatter(clf.support_vectors_[:, 0], clf.support_vectors_[:, 1], s=110,facecolors='none', edgecolors='black')

plt.title("setosa and virginca")
plt.xlabel('petal length (cm)')
plt.ylabel('petal width (cm)')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            2       1.00      1.00      1.00        16
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %%
X=df[['petal length (cm)','petal width (cm)']]
X=X.to_numpy()
y=data.target

model=SVC(kernel='linear',C=0.001)
model.fit(X_train, y_train)
y_pred=model.predict(X_test)

print("C=0.001")
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))

print("C=0.1")
model=SVC(kernel='linear',C=0.1)
model.fit(X_train, y_train)
y_pred=model.predict(X_test)

from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))

print("C=1")
model=SVC(kernel='linear',C=1)
model.fit(X_train, y_train)
y_pred=model.predict(X_test)

from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))

print("C=1000")
model=SVC(kernel='linear',C=1000)
model.fit(X_train, y_train)
y_pred=model.predict(X_test)

from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
# C=0.001
#               precision    recall  f1-score   support
#
#            0       0.47      1.00      0.64        14
#            2       0.00      0.00      0.00        16
#
#     accuracy                           0.47        30
#    macro avg       0.23      0.50      0.32        30
# weighted avg       0.22      0.47      0.30        30
#
# C=0.1
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            2       1.00      1.00      1.00        16
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30
#
# C=1
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            2       1.00      1.00      1.00        16
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# ...

# %%
######### 0 and 1
X=df[['petal length (cm)','petal width (cm)']]
X=X.to_numpy()
y=data.target

X=X[0:100,:]
y=y[0:100]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

from sklearn import svm
from sklearn.svm import SVC

model=SVC(kernel='rbf')
model.fit(X_train, y_train)
y_pred=model.predict(X_test)

from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))

clf=svm.SVC(kernel='rbf')
clf.fit(X, y)


plt.scatter(X[:, 0], X[:, 1], c=y,s=40)
ax = plt.gca()

X1 = np.linspace(ax.get_xlim()[0], ax.get_xlim()[1], 30)
y1 = np.linspace(ax.get_ylim()[0], ax.get_ylim()[1], 30)
y2, X2 = np.meshgrid(y1, X1)

stacked = np.vstack([X2.ravel(), y2.ravel()]).T #returns a flattened array
z = clf.decision_function(stacked).reshape(X2.shape)
ax.scatter(clf.support_vectors_[:, 0], clf.support_vectors_[:, 1], s=110,facecolors='none', edgecolors='black')

ax.contour(X2, y2, z, colors='black', levels=[-1, 0, 1], linestyles=['--', '-', '--'])

plt.xlabel('petal length (cm)')
plt.ylabel('petal width (cm)')
plt.title("setosa and virsicolor")
plt.show()

######## 1 and 2
X=df[['petal length (cm)','petal width (cm)']]
X=X.to_numpy()
y=data.target

X=X[50:150,:]
y=y[50:150]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

from sklearn import svm
from sklearn.svm import SVC

model=SVC(kernel='rbf')
model.fit(X_train, y_train)
y_pred=model.predict(X_test)

from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))

clf=svm.SVC(kernel='rbf')
clf.fit(X, y)


plt.scatter(X[:, 0], X[:, 1], c=y,s=40)
ax = plt.gca()

X1 = np.linspace(ax.get_xlim()[0], ax.get_xlim()[1], 30)
y1 = np.linspace(ax.get_ylim()[0], ax.get_ylim()[1], 30)
y2, X2 = np.meshgrid(y1, X1)

stacked = np.vstack([X2.ravel(), y2.ravel()]).T #returns a flattened array
z = clf.decision_function(stacked).reshape(X2.shape)

ax.contour(X2, y2, z, colors='black', levels=[-1, 0, 1], linestyles=['--', '-', '--'])
ax.scatter(clf.support_vectors_[:, 0], clf.support_vectors_[:, 1], s=110,facecolors='none', edgecolors='black')

plt.xlabel('petal length (cm)')
plt.ylabel('petal width (cm)')
plt.title("virginica and virsicolor")
plt.show()

######## 0 and 2
X=df[['petal length (cm)','petal width (cm)']]
X=X.to_numpy()
y=data.target

#X=X[0:50,:]
X=np.concatenate((X[0:50,:],X[100:150,:]))
y=np.concatenate((y[0:50],y[100:150]))

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

from sklearn import svm
from sklearn.svm import SVC

model=SVC(kernel='linear')
model.fit(X_train, y_train)
y_pred=model.predict(X_test)

from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))

clf=svm.SVC(kernel='linear')
clf.fit(X, y)


plt.scatter(X[:, 0], X[:, 1], c=y,s=40)
ax = plt.gca()

X1 = np.linspace(ax.get_xlim()[0], ax.get_xlim()[1], 30)
y1 = np.linspace(ax.get_ylim()[0], ax.get_ylim()[1], 30)
y2, X2 = np.meshgrid(y1, X1)

stacked = np.vstack([X2.ravel(), y2.ravel()]).T #returns a flattened array
z = clf.decision_function(stacked).reshape(X2.shape)
ax.contour(X2, y2, z, colors='black', levels=[-1, 0, 1], linestyles=['--', '-', '--'])
ax.scatter(clf.support_vectors_[:, 0], clf.support_vectors_[:, 1], s=110,facecolors='none', edgecolors='black')

plt.title("setosa and virginca")
plt.xlabel('petal length (cm)')
plt.ylabel('petal width (cm)')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      1.00      1.00        16
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30
#               precision    recall  f1-score   support
#
#            1       0.86      0.86      0.86        14
#            2       0.88      0.88      0.88        16
#
#     accuracy                           0.87        30
#    macro avg       0.87      0.87      0.87        30
# weighted avg       0.87      0.87      0.87        30
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            2       1.00      1.00      1.00        16
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# ...

# %%
X=df[['petal length (cm)','petal width (cm)']]
X=X.to_numpy()
y=data.target

model=SVC(kernel='rbf',C=0.001)
model.fit(X_train, y_train)
y_pred=model.predict(X_test)

print("C=0.001")
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))

print("C=1")
model=SVC(kernel='rbf',C=1)
model.fit(X_train, y_train)
y_pred=model.predict(X_test)

from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))

print("C=1000")
model=SVC(kernel='rbf',C=1000)
model.fit(X_train, y_train)
y_pred=model.predict(X_test)

from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
# C=0.001
#               precision    recall  f1-score   support
#
#            0       0.47      1.00      0.64        14
#            2       0.00      0.00      0.00        16
#
#     accuracy                           0.47        30
#    macro avg       0.23      0.50      0.32        30
# weighted avg       0.22      0.47      0.30        30
#
# C=1
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            2       1.00      1.00      1.00        16
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30
#
# C=1000
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            2       1.00      1.00      1.00        16
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# ...
